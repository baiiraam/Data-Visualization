# %% [markdown]
# # Import Modules

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Read Files

# %%
olympic = pd.read_csv('C:/Users/Bayram/Downloads/athlete_events.csv/athlete_events.csv')

healthcare=pd.read_csv('C:/Users/Bayram/Downloads/train_data.csv/train_data.csv')

covid_india=pd.read_csv('C:/Users/Bayram/Downloads/covid_19_india.csv')

google_playstore=pd.read_csv('C:/Users/Bayram/Downloads/googleplaystore.csv/googleplaystore.csv')

iris=pd.read_csv('C:/Users/Bayram/Downloads/Iris.csv')

corona_virus = pd.read_csv('C:/Users/Bayram/Downloads/covid_19_data.csv/covid_19_data.csv')

youtube=pd.read_csv('C:/Users/Bayram/Downloads/USvideos.csv/USvideos.csv')

shootings=pd.read_csv('C:/Users/Bayram/Downloads/shootings.csv')

# %% [markdown]
# # Basic Scatter Plot

# %%
sns.scatterplot(x='SepalLengthCm', y='SepalWidthCm', data=iris)
plt.title('Sepal Length vs. Sepal Width')

plt.show()

# %% [markdown]
# ## Scatter Plot - Category

# %%
sns.scatterplot(x='SepalLengthCm', y='SepalWidthCm', hue='Species', data=iris)
plt.title('Sepal Length vs. Sepal Width')

plt.show()

# %% [markdown]
# ## Scatter Plot with Regression Fit

# %%
sns.regplot(x='SepalLengthCm', y='SepalWidthCm', data=iris)
plt.title('Sepal Length vs. Sepal Width with Regression Fit')

plt.show()

# %% [markdown]
# ## Control shape of element in Scatter Plot

# %%
sns.scatterplot(x='SepalLengthCm', y='SepalWidthCm', hue='Species', data=iris, marker='+')
plt.title('Sepal Length vs. Sepal Width')
# Out:
# Text(0.5, 1.0, 'Sepal Length vs. Sepal Width')

# %% [markdown]
# ## Using color Palettes in Scatter Plot

# %%
# using sequencial color scheme
sns.scatterplot(x='Age', y='Height', hue='Sex', data=olympic, palette='Blues')
plt.title('Age vs. Height')
# Out:
# Text(0.5, 1.0, 'Age vs. Height')

# %%
# using diverging color scheme
sns.scatterplot(x='Age', y='Height', hue='Sex', data=olympic, palette='PuOr')
plt.title('Age vs. Height')
# Out:
# Text(0.5, 1.0, 'Age vs. Height')

# %%
# using discrete color scheme
sns.scatterplot(x='Age', y='Height', hue='Sex', data=olympic, palette='Set1')
plt.title('Age vs. Height')
# Out:
# Text(0.5, 1.0, 'Age vs. Height')

# %% [markdown]
# # Line Plot

# %% [markdown]
# ## Basic Line Plot

# %%
sns.lineplot(x='Age', y='Height', data=olympic)
# Out:
# <Axes: xlabel='Age', ylabel='Height'>

# %% [markdown]
# ## Line Plot - Category

# %%
sns.lineplot(x='Age', y='Height', data=olympic, hue='Sex')
# Out:
# <Axes: xlabel='Age', ylabel='Height'>

# %%
sns.lineplot(x='Age', y='Height', data=olympic, estimator=None)
# Out:
# <Axes: xlabel='Age', ylabel='Height'>

# %% [markdown]
# # Histogram Plot

# %% [markdown]
# ## Basic Histogram Plot

# %%
f, ax = plt.subplots(figsize=(7, 5))
sns.despine(f)
sns.histplot(olympic['Age'])
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %% [markdown]
# ## Histogram Plot : Control Number of Bins

# %%
f, ax = plt.subplots(figsize=(7, 5))
sns.despine(f)
sns.distplot(olympic['Age'], bins=20)
# Out:
# C:\Users\Bayram\AppData\Local\Temp\ipykernel_18992\2148376916.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(olympic['Age'], bins=20)
# <Axes: xlabel='Age', ylabel='Density'>

# %% [markdown]
# ## Histogram Plot : Control Density

# %%
f, ax = plt.subplots(figsize=(7, 5))
sns.despine(f)
sns.histplot(olympic['Age'], kde=False)
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %% [markdown]
# ## Basic 1D Density Plot

# %%
f, ax = plt.subplots(figsize=(7,5))
sns.despine(f)
sns.kdeplot(iris['PetalLengthCm'])
# Out:
# <Axes: xlabel='PetalLengthCm', ylabel='Density'>

# %% [markdown]
# ## Density Plot with Shade

# %%
f, ax = plt.subplots(figsize=(7, 5))
sns.despine(f)
sns.kdeplot(iris['PetalLengthCm'], fill=True)
# Out:
# <Axes: xlabel='PetalLengthCm', ylabel='Density'>

# %% [markdown]
# ## Horizontal Density Plot

# %%
f, ax = plt.subplots(figsize=(7, 5))
sns.despine(f)
sns.kdeplot(iris['PetalWidthCm'], vertical=True)
# Out:
# C:\Users\Bayram\AppData\Local\Temp\ipykernel_18992\4069586133.py:3: UserWarning:
#
# The `vertical` parameter is deprecated; assigning data to `y`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(iris['PetalWidthCm'], vertical=True)
# <Axes: xlabel='Density', ylabel='PetalWidthCm'>

# %% [markdown]
# ## Horizontal Density Plot with Shade

# %%
f, ax = plt.subplots(figsize=(7, 5))
sns.despine(f)
sns.kdeplot(iris['PetalWidthCm'], vertical=True, fill=True)
# Out:
# C:\Users\Bayram\AppData\Local\Temp\ipykernel_18992\336082859.py:3: UserWarning:
#
# The `vertical` parameter is deprecated; assigning data to `y`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(iris['PetalWidthCm'], vertical=True, fill=True)
# <Axes: xlabel='Density', ylabel='PetalWidthCm'>

# %% [markdown]
# ## Multi Variable Density Plot

# %%
f, ax = plt.subplots(figsize=(7, 5))
sns.despine(f)
sns.kdeplot(iris['PetalWidthCm'], fill=True)
sns.kdeplot(iris['PetalLengthCm'], fill=True)
plt.show()

# %% [markdown]
# ## Multi Variable Density Plot: Customize Color

# %%
f, ax = plt.subplots(figsize=(7, 5))
sns.despine(f)
sns.kdeplot(iris['SepalLengthCm'], fill=True, color='r')
sns.kdeplot(iris['SepalWidthCm'], fill=True, color='m')
plt.show()

# %% [markdown]
# # 2D Density Plot

# %% [markdown]
# ## Basic 2D Density Plot

# %%
sns.kdeplot(data=[iris['SepalLengthCm'],iris['SepalWidthCm']])

plt.title("Sepal Length vs Sepal Width 2D Density Plot")
# Out:
# Text(0.5, 1.0, 'Sepal Length vs Sepal Width 2D Density Plot')

# %%
sns.kdeplot(data=[iris['SepalLengthCm'], iris['SepalWidthCm']], fill=True, bw_method=.15)
# Out:
# <Axes: ylabel='Density'>

# %% [markdown]
# DID NOT HAPPENED

# %% [markdown]
# # Bar Plot

# %% [markdown]
# ## Basic Bar Plot

# %%
f, ax = plt.subplots(figsize=(7, 5))
sns.despine(f)
sns.barplot(hue='Species', y='SepalLengthCm', data=iris, palette='magma')
# Out:
# <Axes: ylabel='SepalLengthCm'>

# %%
f, ax = plt.subplots(figsize=(7, 5))
sns.despine(f)
sns.barplot(x='Species', y='SepalLengthCm', data=iris, palette='magma')
# Out:
# C:\Users\Bayram\AppData\Local\Temp\ipykernel_18992\3443369070.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Species', y='SepalLengthCm', data=iris, palette='magma')
# <Axes: xlabel='Species', ylabel='SepalLengthCm'>

# %% [markdown]
# ## Horizontal Bar Plot

# %%
f, ax = plt.subplots(figsize=(7, 5))
sns.despine(f)
sns.barplot(x='SepalLengthCm', y='Species', data=iris, palette='magma', orient='h')
# Out:
# C:\Users\Bayram\AppData\Local\Temp\ipykernel_18992\3962677074.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='SepalLengthCm', y='Species', data=iris, palette='magma', orient='h')
# <Axes: xlabel='SepalLengthCm', ylabel='Species'>

# %% [markdown]
# # Box Plot

# %%
sns.boxplot(y=olympic['Age'])
plt.show()

# %% [markdown]
# # Box Plot - Category

# %%
sns.boxplot(x=olympic['Sex'], y=olympic['Height'])
plt.show()

# %% [markdown]
# # Heatmap

# %%
sns.heatmap(iris.drop(['Id'], axis=1).iloc[:,:4].corr())
# Out:
# <Axes: >

# %%
iris.drop(['Id'], axis=1).iloc[:,:4]
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0              5.1           3.5            1.4           0.2
# 1              4.9           3.0            1.4           0.2
# 2              4.7           3.2            1.3           0.2
# 3              4.6           3.1            1.5           0.2
# 4              5.0           3.6            1.4           0.2
# ..             ...           ...            ...           ...
# 145            6.7           3.0            5.2           2.3
# 146            6.3           2.5            5.0           1.9
# 147            6.5           3.0            5.2           2.0
# 148            6.2           3.4            5.4           2.3
# 149            5.9           3.0            5.1           1.8
#
# [150 rows x 4 columns]

# %% [markdown]
# # Violin Plot

# %% [markdown]
# ## Basic Violin Plot

# %%
sns.violinplot(y=shootings['age'])
# Out:
# <Axes: ylabel='age'>

# %% [markdown]
# ## Violin Plot - Category

# %%
sns.violinplot(x=shootings['gender'], y=shootings['age'])
# Out:
# <Axes: xlabel='gender', ylabel='age'>

# %% [markdown]
# ## Horizontal Violin Plot

# %%
sns.violinplot(x=shootings['age'])
# Out:
# <Axes: xlabel='age'>

# %% [markdown]
# ## Horizontal Violin Plot - Category

# %%
sns.violinplot(y=shootings['gender'], x=shootings['age'])
# Out:
# <Axes: xlabel='age', ylabel='gender'>

# %%
sns.violinplot(data=iris.iloc[:,1:5])
# Out:
# <Axes: >

# %% [markdown]
# # Seaborn Themes

# %% [markdown]
# ## Seaborn Dark Grid Theme

# %%
sns.set_style("darkgrid")
sns.scatterplot(x='SepalLengthCm', y='SepalWidthCm', data=iris)
plt.title("Seaborn Dark Grid Theme")
# Out:
# Text(0.5, 1.0, 'Seaborn Dark Grid Theme')

# %% [markdown]
# ## Seaborn Dark Theme

# %%
sns.set_style("dark")
sns.scatterplot(x='SepalLengthCm', y='SepalWidthCm', data=iris)
plt.title("Seaborn Dark Theme")
# Out:
# Text(0.5, 1.0, 'Seaborn Dark Theme')

# %% [markdown]
# ## Seaborn White Grid Theme

# %%
sns.set_style("whitegrid")
sns.scatterplot(x='SepalLengthCm', y='SepalWidthCm', data=iris)
plt.title("Seaborn White Grid Theme")
# Out:
# Text(0.5, 1.0, 'Seaborn White Grid Theme')

# %% [markdown]
# ## Seaborn White Theme

# %%
sns.set_style("white")
sns.scatterplot(x='SepalLengthCm', y='SepalWidthCm', data=iris)
plt.title("Seaborn White Theme")
# Out:
# Text(0.5, 1.0, 'Seaborn White Theme')

# %% [markdown]
# ## Seaborn Ticks Theme

# %%
sns.set_style("ticks")
sns.scatterplot(x='SepalLengthCm', y='SepalWidthCm', data=iris)
plt.title("Seaborn Ticks Theme")
# Out:
# Text(0.5, 1.0, 'Seaborn Ticks Theme')
