# %%
import matplotlib.pyplot as plt

# %%
fig, ax = plt.subplots(2,2)
ax[0,0].plot([1,2,3,4,5,6,7], [1,2,4,6,7,10,12])
ax[0,0].set_title('City A')
ax[0,1].plot([1,2,3,4,5,6,7], [1,2,4,6,7,10,12])
ax[0,1].set_title('City B')
ax[1,0].plot([1,2,3,4,5,6,7], [1,2,4,6,7,10,12])
ax[1,1].plot([1,2,3,4,5,6,7], [1,2,4,6,7,10,12])
